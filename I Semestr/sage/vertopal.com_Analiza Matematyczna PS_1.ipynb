# %% [markdown]
# # Analiza matematyczna - PS
#
# ## Informatyka, sem.I, studia niestacjonarne I stopnia, 2024/25
#
# ### Lista nr 1: Funkcje jednej zmiennej. Własności funkcji
#
# Zad. 1. Sprawdzić, czy podane funkcje są rosnące na wskazanych zbiorach:
#
# a\) \$f(x)=x^2,\\ x\in \langle 0;\infty)\$
#
# b) \$g(x)=\displaystyle\frac{1}{x^4+1},\\ x\in(-\infty;0\rangle\$
#
# c) \$h(x)=\sqrt\[3\]{x},\\ x\in(-\infty;0\rangle;\$
#
# d) \$p(x)=\sqrt{x+1},\\ x\in\langle -1;\infty)\$
#
#
# In \[1\]:
#
#     #a
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x1>=0)
#     f(x) = x^2
#     bool(f(x1)<f(x2))
#
# Out\[1\]:
#
#     True
#
# In \[4\]:
#
#     #b
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x2<=0)
#     g(x) = 1/((x^4)+1)
#     bool(g(x1)<g(x2))
#
# Out\[4\]:
#
#     True
#
# In \[21\]:
#
#     #c
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x2<=0)
#     h(x) = x^(1/3)
#     bool(h(x1)<h(x2))
#     #Bool pokazuje false ze względu na ograniczone możliwości SageMath
#
#     #Alternatywne rozwiązanie:
#     #x1 = -1, x2 = 0, x1<x2, x2<=0
#     bool(h(-1)<h(0))
#
# Out\[21\]:
#
#     True
#
# In \[22\]:
#
#     #d
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x1>=-1)
#     p(x) = (x+1)^(1/2)
#     bool(p(x1)<p(x2))
#     #Bool pokazuje false ze względu na ograniczone możliwości SageMath
#
#     #Alternatywne rozwiązanie:
#     #x1 = -1, x2 = 0, x1<x2, x1>=0
#     bool(p(-1)<p(0))
#
# Out\[22\]:
#
#     True
#
# Zad. 2. Sprawdzić, czy podane funkcje są malejące na wskazanych
# zbiorach:
#
# a\) \$f(x)=3-4x,\\ x\in\mathbb{R}\$
#
# b) \$g(x)=x^2-2x,\\ x\in(-\infty;1\rangle\$
#
# c) \$h(x)=\displaystyle\frac{1}{1+x^2},\\ x\in\langle 0;\infty)\$
#
# d) \$p(x)=\displaystyle\frac{1}{1+x},\\ x\in(-\infty;-1)\$
#
#
# In \[18\]:
#
#     #a
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2)
#     f(x) = 3-4*x
#     bool(f(x1)>f(x2))
#
# Out\[18\]:
#
#     True
#
# In \[32\]:
#
#     #b
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x2<=0)
#     g(x) = x^2-2*x
#     bool(g(x1)>g(x2))
#
# Out\[32\]:
#
#     True
#
# In \[27\]:
#
#     #c
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x1>=0)
#     h(x) = 1/(1+x^2)
#     bool(h(x1)>h(x2)>0)
#
# Out\[27\]:
#
#     True
#
# In \[47\]:
#
#     #d
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1<x2, x2<-1)
#     p(x) = 1/(1+x)
#     bool(p(x1)>p(x2))
#
# Out\[47\]:
#
#     True
#
# Zad. 3. Sprawdzić, czy podane funkcje są różnowartościowe na wskazanych
# zbiorach:
#
# a\) \$f(x)=x^3+1,\\ x\in\mathbb{R}\$
#
# b) \$g(x)=\displaystyle\frac{1}{x^2},\\ x\in(-\infty;0)\$
#
# c) \$h(x)=\sqrt{x}+1,\\ x\in\langle 0;\infty)\$
#
#
# In \[29\]:
#
#     #a
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1!=x2)
#     f(x) = x^3+1
#     bool(f(x1)!=f(x2))
#     #Bool pokazuje false ze względu na ograniczone możliwości SageMath
#
#     #Alternatywne rozwiązanie:
#     #x1 = 1, x2 = -1, x1!=x2
#     bool(f(1)!=f(-1))
#
# Out\[29\]:
#
#     True
#
# In \[30\]:
#
#     #b
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1!=x2, x1<0, x2<0)
#     g(x) = 1/(x^2)
#     bool(g(x1)!=g(x2))
#
# Out\[30\]:
#
#     True
#
# In \[36\]:
#
#     #c
#     forget()
#     x1,x2 = var('x1,x2')
#     assume(x1!=x2, x1>=0, x2>=0)
#     h(x) = x^(1/2)+1
#     bool(h(x1)!=h(x2))
#     #Bool pokazuje false ze względu na ograniczone możliwości SageMath
#
#     #Alternatywne rozwiązanie:
#     #x1 = 0, x2 = 1, x1!=x2, x1>=0, x2>=0
#     bool(h(0)!=h(1))
#
# Out\[36\]:
#
#     True
#
# Zad. 4. Sprawdzić, które z podanych funkcji są parzyste, a które
# nieparzyste:
#
# a\) \$\displaystyle f(x)=x^4-3x^2+1\$
#
# b) \$\displaystyle g(x)=2^x+2^{-x}\$
#
# c) \$\displaystyle h(x)=\|\sin x\|\$
#
# d) \$\displaystyle p(x)=\frac{\sin x}{x^3}\$
#
# e) \$\displaystyle f(x)=\frac{2+x^2}{x^5},\$
#
# f) \$\displaystyle g(x)=\sin^3 x\$
#
# g) \$\displaystyle h(x)=3^x-3^{-x}\$
#
# h) \$\displaystyle p(x)=x\|x\|\$
#
#
# In \[51\]:
#
#     #a
#     f(x) = x^4-3*x^2+1
#     bool(f(x)==f(-x))
#
# Out\[51\]:
#
#     True
#
# In \[52\]:
#
#     #b
#     g(x) = 2^x+2^-x
#     bool(g(x)==g(-x))
#
# Out\[52\]:
#
#     True
#
# In \[62\]:
#
#     #c
#     h(x) = abs(sin(x))
#     bool(h(x)==h(-x))
#
# Out\[62\]:
#
#     True
#
# In \[74\]:
#
#     #d
#     forget()
#     assume(x!=0)
#     p(x) = sin(x)/(x^3)
#     bool(p(x)==p(-x))
#
# Out\[74\]:
#
#     True
#
# In \[183\]:
#
#     #e
#     forget()
#     assume(x!=0)
#     f(x) = (2+x^2)/(x^5)
#     bool(f(x)==f(-x))
#
# Out\[183\]:
#
#     False
#
# In \[196\]:
#
#     #f
#     g(x) = sin(x)^3
#     bool(g(x)==g(-x))
#
# Out\[196\]:
#
#     False
#
# In \[185\]:
#
#     #g
#     h(x) = 3^x-3^(-x)
#     bool(h(x)==h(-x))
#
# Out\[185\]:
#
#     False
#
# In \[77\]:
#
#     #h
#     p(x) = x*abs(x)
#     bool(p(x)==p(-x))
#
# Out\[77\]:
#
#     False
#
# Zad. 5. Określić funkcje złożone \$f\circ f\$, \$f\circ g\$, \$g\circ
# f\$, \$g\circ g\$ oraz ich dziedziny, jeżeli:
#
# a\) \$\displaystyle f(x)=\|x\|, \\ g(x)=-3x+2\$
#
# b) \$\displaystyle f(x)=\sqrt{x},\\ g(x)=x^3+1\$
#
# c) \$\displaystyle f(x)=x^2,\\ g(x)=\sqrt{x},\$
#
# d) \$\displaystyle f(x)=2^x,\\ g(x)=\cos x\$
#
# e) \$\displaystyle f(x)=x^3,\\ g(x)=\frac{1}{\sqrt\[3\]{x}}\$
#
# f) \$\displaystyle f(x)=\frac{x}{1+x^2},\\ g(x)=\frac{1}{x},\$
#
# g) \$\displaystyle f(x)=\log x,\\ g(x)=x^2+1.\$
#
# In \[194\]:
#
#     #a
#     f(x) = abs(x)
#     g(x) = -3*x+2
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| {\left| x \right|}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| {\left| -3 \, x + 2 \right|}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| -3 \, {\left| x \right|} + 2$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| 9 \, x - 4$$
#
# In \[187\]:
#
#     #b
#     f(x) = x^(1/2)
#     g(x) = x^3+1
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R\{-1}
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| x^{\frac{1}{4}}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| \sqrt{x^{3} + 1}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| x^{\frac{3}{2}} + 1$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| {\left(x^{3} + 1\right)}^{3} + 1$$
#
# In \[94\]:
#
#     #c
#     f(x) = x^2
#     g(x) = x^(1/2)
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| x^{4}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| x$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| \sqrt{x^{2}}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| x^{\frac{1}{4}}$$
#
# In \[96\]:
#
#     #d
#     f(x) = 2^x
#     g(x) = cos(x)
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| 2^{\left(2^{x}\right)}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| 2^{\cos\left(x\right)}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| \cos\left(2^{x}\right)$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| \cos\left(\cos\left(x\right)\right)$$
#
# In \[98\]:
#
#     #e
#     f(x) = x^3
#     g(x) = 1/(x^(1/3))
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R\{0}
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R\{0}
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| x^{9}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| \frac{1}{x}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| \frac{1}{{\left(x^{3}\right)}^{\frac{1}{3}}}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| x^{\frac{1}{9}}$$
#
# In \[100\]:
#
#     #f
#     f(x) = x/(1+x^2)
#     g(x) = 1/x
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do R
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R\{0}
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do R\{0}
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| \frac{x}{{\left(x^{2} + 1\right)} {\left(\frac{x^{2}}{{\left(x^{2} + 1\right)}^{2}} + 1\right)}}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| \frac{1}{x {\left(\frac{1}{x^{2}} + 1\right)}}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| \frac{x^{2} + 1}{x}$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| x$$
#
# In \[106\]:
#
#     #g
#     f(x) = log(x)
#     g(x) = x^2+1
#
#     show('f∘f =', f(f(x)))
#     #Dziedzina f∘f, x należy do (1, ∞)
#
#     show('f∘g =', f(g(x)))
#     #Dziedzina f∘g, x należy do R
#
#     show('g∘f =', g(f(x)))
#     #Dziedzina g∘f, x należy do (0, ∞)
#
#     show('g∘g =', g(g(x)))
#     #Dziedzina g∘g, x należy do R
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘f|\verb| |\verb|=| \log\left(\log\left(x\right)\right)$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|f∘g|\verb| |\verb|=| \log\left(x^{2} + 1\right)$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘f|\verb| |\verb|=| \log\left(x\right)^{2} + 1$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\verb|g∘g|\verb| |\verb|=| {\left(x^{2} + 1\right)}^{2} + 1$$
#
# Zad. 6. Znaleźć funkcję odwrotną do podanej:
#
# a\) \$\displaystyle f(x)=x^2-2x,\\ x\in\langle 1;\infty)\$
#
# b) \$\displaystyle g(x)=2-\sqrt\[5\]{x+1},\\ x\in\mathbb{R}\$
#
# c) \$\displaystyle h(x)=x^3\|x\|,\\ x\in\mathbb{R},\$
#
# d) \$\displaystyle p(x)=\left\\{ \begin{array}{rrr} 3^x & \mbox{ dla }
# &x\<0\\\\ 5^x & \mbox{ dla } &x\geqslant 0 \end{array}\right. ,\\
# x\in\mathbb{R}\$
#
# e) \$\displaystyle f(x)=1-3^{-x}\$
#
# f) \$\displaystyle g(x)=x^5+\sqrt{3},\$
#
# g) \$\displaystyle h(x)=x^6\mathrm{sgn\\,}x\$
#
# h) \$\displaystyle q(x)=\left\\{ \begin{array}{rrr} -x^2 & \mbox{ dla }
# &x\<0\\\\ 2+x & \mbox{ dla } &x\geqslant 0 \end{array}\right. ,\\
# x\in\mathbb{R}\$
#
# i) \$\displaystyle f(x)=\frac{x}{1+\|x\|}.\$
#
# In \[197\]:
#
#     #a
#     forget()
#     assume(x>=1)
#     f(x) = x^2-2*x
#     show(solve(y==f(x),x))
#     #Rozwiązanie drugie jest poprawne ponieważ, pierwsza jest mniejsza od 1
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x = -\sqrt{y + 1} + 1, x = \sqrt{y + 1} + 1\right]$$
#
# In \[200\]:
#
#     #b
#     forget()
#     g(x) = 2-(x+1)^(1/5)
#
# In \[203\]:
#
#     #c
#     forget()
#     assume(x, 'real')
#     h(x) = x^3*abs(x)
#     show(solve(y==h(x),x))
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x^{3} = \frac{y}{{\left| x \right|}}\right]$$
#
# In \[204\]:
#
#     #d
#     forget()
#     assume(x<0)
#     p1(x) = 3^x
#     show(solve(y==p1(x),x))
#
#     forget()
#     assume(x>=0)
#     p2(x) = 5^x
#     show(solve(y==p2(x),x))
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x = \frac{\log\left(y\right)}{\log\left(3\right)}\right]$$
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x = \frac{\log\left(y\right)}{\log\left(5\right)}\right]$$
#
# In \[205\]:
#
#     #e
#     forget()
#     assume(x, 'real')
#     f(x) = 1-3^(-x)
#     show(solve(y==f(x),x))
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x = \frac{\log\left(-\frac{1}{y - 1}\right)}{\log\left(3\right)}\right]$$
#
# In \[207\]:
#
#     #f
#     forget()
#     g(x) = x^5+sqrt(3)
#     show(solve(y==g(x),x))
#
# $$\newcommand{\Bold}[1]{\mathbf{#1}}\left[x = \frac{1}{4} \, {\left(y - \sqrt{3}\right)}^{\frac{1}{5}} {\left(\sqrt{5} + i \, \sqrt{2 \, \sqrt{5} + 10} - 1\right)}, x = -\frac{1}{4} \, {\left(y - \sqrt{3}\right)}^{\frac{1}{5}} {\left(\sqrt{5} - i \, \sqrt{-2 \, \sqrt{5} + 10} + 1\right)}, x = -\frac{1}{4} \, {\left(y - \sqrt{3}\right)}^{\frac{1}{5}} {\left(\sqrt{5} + i \, \sqrt{-2 \, \sqrt{5} + 10} + 1\right)}, x = \frac{1}{4} \, {\left(y - \sqrt{3}\right)}^{\frac{1}{5}} {\left(\sqrt{5} - i \, \sqrt{2 \, \sqrt{5} + 10} - 1\right)}, x = {\left(y - \sqrt{3}\right)}^{\frac{1}{5}}\right]$$
